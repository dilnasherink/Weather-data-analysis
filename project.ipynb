# %% [markdown]
# # GLOBAL WEATHER DATA ANALYSIS

# %% [markdown]
# - This is an analysis project to understand the weather of countries in 2024

# %%
import pandas as pd # data handling
import matplotlib.pyplot as plt # visualization
import seaborn as sns # visualization

# %% [markdown]
# - pandas for data manipulation
# - matplotlib and seaborn for visualization

# %% [markdown]
# ## LOADING DATASET

# %%
df=pd.read_csv("weather.csv")
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %% [markdown]
# ## inspecting data

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100   2024-05-16 9:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100   2024-05-16 9:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.tail()
# Out:
#           country location_name  latitude  longitude         timezone  \
# 136628  Venezuela       Caracas   10.5000   -66.9167  America/Caracas
# 136629    Vietnam         Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630      Yemen         Sanaa   15.3547    44.2067        Asia/Aden
# 136631     Zambia        Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632   Zimbabwe        Harare  -17.8178    31.0447    Africa/Harare
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# 136628          1776666600   2026-04-20 2:30                 17.5
# 136629          1776666600  2026-04-20 13:30                 28.3
# 136630          1776666600   2026-04-20 9:30                 21.0
# 136631          1776666600   2026-04-20 8:30                 21.5
# 136632          1776666600   2026-04-20 8:30                 20.0
#
#         temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 136628                    63.6  Partly Cloudy  ...               7.85
# ...

# %%
df.sample()
# Out:
#         country location_name  latitude  longitude       timezone  \
# 126290  Austria        Vienna      48.2    16.3667  Europe/Vienna
#
#         last_updated_epoch     last_updated  temperature_celsius  \
# 126290          1772088300  2026-02-26 7:45                  2.0
#
#         temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 126290                    35.6          Sunny  ...              26.05
#
#         air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# 126290             33.05                         2                          3
#
#         sunrise   sunset  moonrise  moonset      moon_phase  moon_illumination
# 126290  6:42 AM  5:34 PM  11:16 AM  3:52 AM  Waxing Gibbous                 66
#
# [1 rows x 41 columns]

# %% [markdown]
# ## checking data types

# %%
df.dtypes
# Out:
# country                          object
# location_name                    object
# latitude                        float64
# longitude                       float64
# timezone                         object
# last_updated_epoch                int64
# last_updated                     object
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                       int64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# ...

# %%
df.shape
# Out:
# (136633, 41)

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136633 entries, 0 to 136632
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       136633 non-null  object
#  1   location_name                 136633 non-null  object
#  2   latitude                      136633 non-null  float64
#  3   longitude                     136633 non-null  float64
#  4   timezone                      136633 non-null  object
#  5   last_updated_epoch            136633 non-null  int64
#  6   last_updated                  136633 non-null  object
#  7   temperature_celsius           136633 non-null  float64
#  8   temperature_fahrenheit        136633 non-null  float64
#  9   condition_text                136633 non-null  object
#  10  wind_mph                      136633 non-null  float64
#  11  wind_kph                      136633 non-null  float64
# ...

# %% [markdown]
# ## informations

# %% [markdown]
# - number of columns = 41
# - number of rows = 136633
# - missing values = 0
# - memory usage = 42.7+ MB
# - sunrise,moonset and sunset times stored as object
# - last_update stored as object

# %% [markdown]
# ## Data types

# %% [markdown]
# - float = 21
# - integer = 9
# - objects = 11

# %% [markdown]
# ## selecting columns

# %% [markdown]
# - selecting sinle columns

# %%
df['country']
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3             Andorra
# 4              Angola
#              ...
# 136628      Venezuela
# 136629        Vietnam
# 136630          Yemen
# 136631         Zambia
# 136632       Zimbabwe
# Name: country, Length: 136633, dtype: object

# %%
df[['sunrise','sunset']]
# Out:
#         sunrise   sunset
# 0       4:50 AM  6:50 PM
# 1       5:21 AM  7:54 PM
# 2       5:40 AM  7:50 PM
# 3       6:31 AM  9:11 PM
# 4       6:12 AM  5:55 PM
# ...         ...      ...
# 136628  6:14 AM  6:39 PM
# 136629  5:34 AM  6:17 PM
# 136630  5:46 AM  6:18 PM
# 136631  6:15 AM  5:56 PM
# 136632  6:06 AM  5:43 PM
#
# [136633 rows x 2 columns]

# %%
place=df[['country','location_name']]

# %%
place
# Out:
#             country     location_name
# 0       Afghanistan             Kabul
# 1           Albania            Tirana
# 2           Algeria           Algiers
# 3           Andorra  Andorra La Vella
# 4            Angola            Luanda
# ...             ...               ...
# 136628    Venezuela           Caracas
# 136629      Vietnam             Hanoi
# 136630        Yemen             Sanaa
# 136631       Zambia            Lusaka
# 136632     Zimbabwe            Harare
#
# [136633 rows x 2 columns]

# %% [markdown]
# ## filter the data

# %%
df[df['temperature_celsius']==25]
# Out:
#                                  country location_name  latitude  longitude  \
# 31                              Cameroon       Yaounde    3.8700    11.5200
# 43                                Cyprus       Nicosia   35.1700    33.3700
# 82                                Israel     Jerusalem   31.7800    35.2300
# 144                               Rwanda        Kigali   -1.9500    30.0600
# 172                             Tanzania        Dodoma   -6.1800    35.7500
# ...                                  ...           ...       ...        ...
# 136101                 Equatorial Guinea        Malabo    3.7500     8.7833
# 136389                       Saint Lucia      Castries   14.0000   -61.0000
# 136390  Saint Vincent and the Grenadines     Kingstown   13.1333   -61.2167
# 136483      Democratic Republic of Congo      Kinshasa   -4.3000    15.3000
# 136486                          Dominica        Roseau   15.3000   -61.4000
#
# ...

# %%
df[df['moon_phase']=='New Moon']
# Out:
#                 country     location_name  latitude  longitude  \
# 4285        Afghanistan             Kabul   34.5200    69.1800
# 4286            Albania            Tirana   41.3300    19.8200
# 4287            Algeria           Algiers   36.7600     3.0500
# 4288            Andorra  Andorra La Vella   42.5000     1.5200
# 4289             Angola            Luanda   -8.8400    13.2300
# ...                 ...               ...       ...        ...
# 136196            Samoa              Apia  -13.8333  -171.7333
# 136207  Solomon Islands           Honiara   -9.4333   159.9500
# 136224            Tonga        Nuku`Aloia  -21.1333  -175.2000
# 136229           Tuvalu          Funafuti   -8.5167   179.2167
# 136237          Vanuatu         Port Vila  -17.7333   168.3167
#
#                    timezone  last_updated_epoch      last_updated  \
# 4285             Asia/Kabul          1717682400  2024-06-06 18:30
# 4286          Europe/Tirane          1717682400  2024-06-06 16:00
# ...

# %%
df[df['condition_text']=='Sunny']
# Out:
#                      country location_name  latitude  longitude  \
# 2                    Algeria       Algiers   36.7600     3.0500
# 12                   Bahrain        Manama   26.2400    50.5800
# 15                   Belarus         Minsk   53.9000    27.5700
# 22                  Botswana      Gaborone  -24.6500    25.9100
# 28                Madagascar         Ivory  -24.3700    46.4500
# ...                      ...           ...       ...        ...
# 136622  United Arab Emirates     Abu Dhabi   24.4667    54.3667
# 136623        United Kingdom        London   51.5171    -0.1062
# 136630                 Yemen         Sanaa   15.3547    44.2067
# 136631                Zambia        Lusaka  -15.4167    28.2833
# 136632              Zimbabwe        Harare  -17.8178    31.0447
#
#                    timezone  last_updated_epoch      last_updated  \
# 2            Africa/Algiers          1715849100   2024-05-16 9:45
# ...

# %%
df[df['moon_phase']=='Waxing Gibbous']
# Out:
#             country     location_name  latitude  longitude        timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800      Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200   Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500  Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200  Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300   Africa/Luanda
# ...             ...               ...       ...        ...             ...
# 132922      Vanuatu         Port Vila  -17.7333   168.3167   Pacific/Efate
# 132924      Vietnam             Hanoi   21.0333   105.8500    Asia/Bangkok
# 132925        Yemen             Sanaa   15.3547    44.2067       Asia/Aden
# 132926       Zambia            Lusaka  -15.4167    28.2833   Africa/Lusaka
# 132927     Zimbabwe            Harare  -17.8178    31.0447   Africa/Harare
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# ...

# %%
df[df['condition_text']=='Clear']
# Out:
#                          country      location_name  latitude  longitude  \
# 6                      Argentina       Buenos Aires  -34.5900   -58.6700
# 8                      Australia           Canberra  -35.2800   149.2200
# 20                       Bolivia              Sucre  -19.0400   -65.2600
# 35                         Chile           Santiago  -33.4500   -70.6700
# 42                          Cuba             Havana   23.1300   -82.3600
# ...                          ...                ...       ...        ...
# 136522                   Jamaica           Kingston   18.0000   -76.8000
# 136543                      Mali             Bamako   12.6500    -8.0000
# 136574                  Paraguay          Garrapata  -19.7000   -58.7167
# 136575                      Peru               Lima  -12.0500   -77.0500
# 136624  United States of America  Washington Harbor   48.0792  -123.0439
#
#                               timezone  last_updated_epoch      last_updated  \
# ...

# %%
df[df['moon_phase']=='Waning Gibbous']
# Out:
#             country     location_name  latitude  longitude        timezone  \
# 1751    Afghanistan             Kabul   34.5200    69.1800      Asia/Kabul
# 1752        Albania            Tirana   41.3300    19.8200   Europe/Tirane
# 1753        Algeria           Algiers   36.7600     3.0500  Africa/Algiers
# 1754        Andorra  Andorra La Vella   42.5000     1.5200  Europe/Andorra
# 1755         Angola            Luanda   -8.8400    13.2300   Africa/Luanda
# ...             ...               ...       ...        ...             ...
# 134482      Vanuatu         Port Vila  -17.7333   168.3167   Pacific/Efate
# 134484      Vietnam             Hanoi   21.0333   105.8500    Asia/Bangkok
# 134485        Yemen             Sanaa   15.3547    44.2067       Asia/Aden
# 134486       Zambia            Lusaka  -15.4167    28.2833   Africa/Lusaka
# 134487     Zimbabwe            Harare  -17.8178    31.0447   Africa/Harare
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# ...

# %% [markdown]
# ## filtering with multiple conditions

# %%
df[(df['moon_phase']=='New Moon') & (df['temperature_celsius']==25)]
# Out:
#                              country  location_name  latitude  longitude  \
# 4319                           China        Beijing   39.9300   116.3900
# 4370                      Kazakhstan         Astana   51.1800    71.4300
# 4381                   Liechtenstein          Vaduz   47.1300     9.5200
# 4404                           Nepal      Kathmandu   27.7200    85.3200
# 4409                         Nigeria          Abuja    9.1800     7.1800
# 4415                           Palau          Adkip    7.3600   134.5100
# 4421                     Philippines         Manila   14.6000   120.9800
# 4442                 Solomon Islands        Honiara   -9.4300   159.9500
# 15338                         France          Paris   48.8700     2.3300
# 20982             Dominican Republic  Santo Domingo   18.4700   -69.9000
# 21050                     Mozambique         Maputo  -25.9700    32.5900
# 26815       Central African Republic         Bangui    4.3700    18.5800
# ...

# %% [markdown]
# ## selecting rows - iloc method

# %%
df.iloc[9] # single row
df.iloc[4:11] # portion
# Out:
#                 country location_name  latitude  longitude  \
# 4                Angola        Luanda     -8.84      13.23
# 5   Antigua and Barbuda  Saint John's     17.12     -61.85
# 6             Argentina  Buenos Aires    -34.59     -58.67
# 7               Armenia       Yerevan     40.18      44.51
# 8             Australia      Canberra    -35.28     149.22
# 9               Austria        Vienna     48.20      16.37
# 10           Azerbaijan          Baku     40.40      49.88
#
#                           timezone  last_updated_epoch      last_updated  \
# 4                    Africa/Luanda          1715849100   2024-05-16 9:45
# 5                  America/Antigua          1715849100   2024-05-16 4:45
# 6   America/Argentina/Buenos_Aires          1715849100   2024-05-16 5:45
# 7                     Asia/Yerevan          1715849100  2024-05-16 12:45
# 8                 Australia/Sydney          1715849100  2024-05-16 18:45
# ...

# %%
df.iloc[9]
# Out:
# country                                  Austria
# location_name                             Vienna
# latitude                                    48.2
# longitude                                  16.37
# timezone                           Europe/Vienna
# last_updated_epoch                    1715849100
# last_updated                    2024-05-16 10:45
# temperature_celsius                         16.0
# temperature_fahrenheit                      60.8
# condition_text                     Partly cloudy
# wind_mph                                    12.5
# wind_kph                                    20.2
# wind_degree                                  110
# wind_direction                               ESE
# pressure_mb                                 1013
# pressure_in                                29.91
# precip_mm                                    0.0
# precip_in                                    0.0
# humidity                                      63
# ...

# %% [markdown]
# ## loc method

# %%
df.loc[100,'sunrise']
# Out:
# '5:49 AM'

# %% [markdown]
# ## rename column

# %%
df.rename(columns={"country":"place"})
# Out:
#               place     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df.rename(columns={"condition_text":"weather","temperature_celsius":"temp_celsius"},inplace=True)

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df['weather'].value_counts()
# Out:
# weather
# Partly cloudy                                  39376
# Sunny                                          39229
# Patchy rain nearby                             11376
# Partly Cloudy                                   8669
# Overcast                                        7410
# Clear                                           7200
# Mist                                            5716
# Light rain                                      4287
# Light rain shower                               3133
# Fog                                             1709
# Cloudy                                          1633
# Moderate or heavy rain with thunder             1090
# Moderate rain                                   1042
# Patchy light rain with thunder                   843
# Light drizzle                                    678
# Light snow                                       523
# Patchy light drizzle                             455
# Moderate or heavy rain shower                    287
# ...

# %%
df['moon_phase'].value_counts()
# Out:
# moon_phase
# Waning Crescent    29886
# Waxing Crescent    29481
# Waxing Gibbous     29382
# Waning Gibbous     28477
# Full Moon           4933
# Last Quarter        4920
# New Moon            4876
# First Quarter       4678
# Name: count, dtype: int64

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Clean Numericals columns with characters

# %%
df['sunrise']=pd.to_numeric(
    df['sunrise']
    .astype(str)
    .str.replace(r'[^0-9,-]','',regex=True)
    .replace('',None),
    errors='coerce'
)

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df["last_updated"] = pd.to_datetime(df["last_updated"],
                                    errors="coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136633 entries, 0 to 136632
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       136633 non-null  object
#  1   location_name                 136633 non-null  object
#  2   latitude                      136633 non-null  float64
#  3   longitude                     136633 non-null  float64
#  4   timezone                      136633 non-null  object
#  5   last_updated_epoch            136633 non-null  int64
#  6   last_updated                  136633 non-null  datetime64[ns]
#  7   temp_celsius                  136633 non-null  float64
#  8   temperature_fahrenheit        136633 non-null  float64
#  9   weather                       136633 non-null  object
#  10  wind_mph                      136633 non-null  float64
#  11  wind_kph                      136633 non-null  float64
# ...

# %%
df.dtypes
# Out:
# country                                 object
# location_name                           object
# latitude                               float64
# longitude                              float64
# timezone                                object
# last_updated_epoch                       int64
# last_updated                    datetime64[ns]
# temp_celsius                           float64
# temperature_fahrenheit                 float64
# weather                                 object
# wind_mph                               float64
# wind_kph                               float64
# wind_degree                              int64
# wind_direction                          object
# pressure_mb                              int64
# pressure_in                            float64
# precip_mm                              float64
# precip_in                              float64
# humidity                                 int64
# cloud                                    int64
# ...

# %% [markdown]
# ## deleting unwanted columns

# %%
df.drop(columns=['sunrise'],inplace=True)

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df.drop(columns=['sunset','moonrise','moonset','moon_phase','moon_illumination'],inplace=True)

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df.drop(columns=['temperature_fahrenheit','wind_mph','precip_in','visibility_miles','gust_mph','pressure_in','feels_like_fahrenheit'],inplace=True)

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df.shape
# Out:
# (136633, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136633 entries, 0 to 136632
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       136633 non-null  object
#  1   location_name                 136633 non-null  object
#  2   latitude                      136633 non-null  float64
#  3   longitude                     136633 non-null  float64
#  4   timezone                      136633 non-null  object
#  5   last_updated_epoch            136633 non-null  int64
#  6   last_updated                  136633 non-null  datetime64[ns]
#  7   temp_celsius                  136633 non-null  float64
#  8   weather                       136633 non-null  object
#  9   wind_kph                      136633 non-null  float64
#  10  wind_degree                   136633 non-null  int64
#  11  wind_direction                136633 non-null  object
# ...

# %% [markdown]
# ## Handling missing values

# %%
df.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temp_celsius                    0
# weather                         0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# precip_mm                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# visibility_km                   0
# uv_index                        0
# gust_kph                        0
# air_quality_Carbon_Monoxide     0
# air_quality_Ozone               0
# air_quality_Nitrogen_dioxide    0
# air_quality_Sulphur_dioxide     0
# air_quality_PM2.5               0
# air_quality_PM10                0
# air_quality_us-epa-index        0
# ...

# %% [markdown]
# - no missing values in this dataset
# - filling with median(numerical) and with mode(categorical)

# %%
df['temp_celsius'].median()
# Out:
# 23.9

# %%
df['temp_celsius'].mode()
# Out:
# 0    25.1
# Name: temp_celsius, dtype: float64

# %%
df.drop(columns=['last_updated_epoch'],inplace=True)

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %% [markdown]
# - finding mean,median and mode of columns

# %%
print(df.select_dtypes(include='number').mean())
# Out:
# latitude                          19.211173
# longitude                         21.956700
# temp_celsius                      21.268191
# wind_kph                          12.897045
# wind_degree                      168.797348
# pressure_mb                     1014.064304
# precip_mm                          0.134168
# humidity                          66.661553
# cloud                             39.976228
# feels_like_celsius                22.120190
# visibility_km                      9.507450
# uv_index                           3.313816
# gust_kph                          18.242712
# air_quality_Carbon_Monoxide      459.169559
# air_quality_Ozone                 57.997988
# air_quality_Nitrogen_dioxide      14.974117
# air_quality_Sulphur_dioxide       10.315061
# air_quality_PM2.5                 24.149276
# air_quality_PM10                  48.293201
# air_quality_us-epa-index           1.697430
# air_quality_gb-defra-index         2.601275
# dtype: float64

# %%
print(df.select_dtypes(include='number').median())
# Out:
# latitude                          17.2500
# longitude                         23.2361
# temp_celsius                      23.9000
# wind_kph                          10.8000
# wind_degree                      161.0000
# pressure_mb                     1014.0000
# precip_mm                          0.0000
# humidity                          72.0000
# cloud                             30.0000
# feels_like_celsius                25.1000
# visibility_km                     10.0000
# uv_index                           1.9000
# gust_kph                          15.3000
# air_quality_Carbon_Monoxide      293.7000
# air_quality_Ozone                 55.0000
# air_quality_Nitrogen_dioxide       5.6500
# air_quality_Sulphur_dioxide        2.4050
# air_quality_PM2.5                 14.1500
# air_quality_PM10                  19.9800
# air_quality_us-epa-index           1.0000
# air_quality_gb-defra-index         2.0000
# dtype: float64

# %%
print(df.select_dtypes(include='object').mode())
# Out:
#      country location_name      timezone        weather wind_direction
# 0   Bulgaria         Accra  Asia/Bangkok  Partly cloudy              E
# 1        NaN         Amman           NaN            NaN            NaN
# 2        NaN        Asmara           NaN            NaN            NaN
# 3        NaN       Baghdad           NaN            NaN            NaN
# 4        NaN          Bern           NaN            NaN            NaN
# 5        NaN     Bujumbura           NaN            NaN            NaN
# 6        NaN         Dakar           NaN            NaN            NaN
# 7        NaN         Kabul           NaN            NaN            NaN
# 8        NaN          Kyiv           NaN            NaN            NaN
# 9        NaN        Malabo           NaN            NaN            NaN
# 10       NaN     N'djamena           NaN            NaN            NaN
# 11       NaN           Nan           NaN            NaN            NaN
# ...
